# %%
from scipy.optimize import minimize 
import numpy as np
import pandas as pd
df=pd.read_csv("Dataset B.csv")
x = df['Feature_X'].values
y = df['Target_Y'].values

# %%
def mse_loss(params, x, y): 
    m, c = params 
    y_hat = m * x + c 
    mse=(y-y_hat)*(y-y_hat)
    return np.mean(mse)

# %%
def mae_loss(params, x, y): 
    m, c = params 
    y_hat = m * x + c 
    mae=abs(y-y_hat)
    return np.mean(mae)

# %%
initial_guess = [0, 0] 
result_mse = minimize(mse_loss, initial_guess, args=(x, y)) 
m_mse, c_mse = result_mse.x 

initial_guess = [0, 0] 
result_mae = minimize(mae_loss, initial_guess, args=(x, y)) 
m_mae, c_mae = result_mae.x

# %%
def analyze_line(x, y, m, c): 
    y_pred = m * x + c 
    residuals = y - y_pred
    return residuals

# %%
m=0
n=0
mr=np.ones(2000)
nr=np.ones(2000)
p=list(range(0,2000))
r=analyze_line(x,y,m_mae,c_mae)
print(r)
for i in p:
    if r[i]>0:
        m=m+1
        mr[i]=r[i]
    if r[i]<0:
        n=n+1
        nr[i]=r[i]
# Out:
# [ 0.72902796 -0.22348881  0.95539136 ... -1.43688247 -0.35872002
#  -1.23152263]

# %%
meanAboveResi=np.mean(mr)
meanAboveResi
# Out:
# np.float64(1.089828013510848)

# %%
meanBelowResi=np.mean(nr)
meanBelowResi
# Out:
# np.float64(-0.08730776271943098)

# %%
import matplotlib.pyplot as plt
y_pred=m_mae*x+c_mae
y_pred1=m_mse*x+c_mse
plt.figure(figsize=(10,6))
plt.scatter(x,y,color="blue",alpha=0.5,label='Original Data')
plt.plot(x, y_pred, color='red', linewidth=2, label=f'Fit: y = {m_mae:.2f}x + {c_mae:.2f}') 
plt.plot(x, y_pred1, color='green', linewidth=2, label=f'Fit: y = {m_mse:.2f}x + {c_mse:.2f}') 
plt.title('Linear Regression using scipy.optimize.minimize', fontsize=14) 
plt.xlabel('x', fontsize=12) 
plt.ylabel('y', fontsize=12) 
plt.legend() 
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
l=0
k=0
l1=0
k1=0
for i in p:
    if y_pred[i]>y[i]:
        k=k+1
    if y_pred[i]<y[i]:
        l=l+1
for i in p:
    if y_pred1[i]>y[i]:
        k1=k1+1
    if y_pred1[i]<y[i]:
        l1=l1+1
print("MAE counts above line {}".format(l))
print("MAE counts below line {}".format(k))
print("MSE counts above line {}".format(l1))
print("MSE counts below line {}".format(k1))
# Out:
# MAE counts above line 1000
# MAE counts below line 1000
# MSE counts above line 995
# MSE counts below line 1005

# %%
import statistics
L=list(range(0,2000))
K=list(range(0,2000))
L1=list(range(0,2000))
K1=list(range(0,2000))
for i in p:
    K[i]=0
    L[i]=0
    if y_pred[i]>y[i]:
        K[i]=(abs(y_pred[i]-y[i]))   
    if y_pred[i]<y[i]:
        L[i]=(abs(y_pred[i]-y[i]))
for i in p:
    K1[i]=0
    L1[i]=0
    if y_pred1[i]>y[i]:
        K1[i]=(abs(y_pred1[i]-y[i]))
    if y_pred1[i]<y[i]:
        L1[i]=(abs(y_pred1[i]-y[i]))
print("MAE mean distance above line {}".format(statistics.mean(L)))
print("MAE mean distance below line {}".format(statistics.mean(K)))
print("MSE mean distance above line {}".format(statistics.mean(L1)))
print("MSE mean distance below line {}".format(statistics.mean(K1)))
# Out:
# MAE mean distance above line 0.5898280135108481
# MAE mean distance below line 0.587307762719431
# MSE mean distance above line 0.5885835321748102
# MSE mean distance below line 0.5885835403042424
